# %% [markdown]
# # ❤️ Our Love Story in Data - Valentine's Day Special

# %% [markdown]
# ## Introduction
# Welcome to our special Valentine's Day Jupyter Notebook! This notebook celebrates our relationship through fun data insights, visualizations, and milestones. Love isn't just about numbers, but let's explore our story using data! 💖

# %% [markdown]
# ## Importing Libraries to tell our story (Not Important)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ## Key Relationship Stats

# %%
# Define important dates
start_date = datetime(2024, 1, 22)  # Your relationship start date
today = datetime.today()

# Calculate days together
days_together = (today - start_date).days

print(f"We have been together for {days_together} days! ❤️")
# Out:
# We have been together for 378 days! ❤️

# %% [markdown]
# ## Timeline of Key Events

# %%
events = {
    "First Date": "2024-01-22",
    "First 'I Love You'": "2024-02-14",
    "First Trip Together": "2024-04-27",
    "First Wedding Attended": "2024-05-11",
    "Anniversary": "2025-01-22","6-Month Photoshoot": "2024-08-16",
}



# Convert dates to pandas datetime
dates = pd.to_datetime(list(events.values()))
labels = list(events.keys())

# Alternating label positions (above and below the timeline)
positions = [1.02 if i % 2 == 0 else 0.98 for i in range(len(labels))]
alignments = ['top' if i % 2 == 0 else 'bottom' for i in range(len(labels))]

# Create the timeline plot
plt.figure(figsize=(10, 3))
plt.hlines(1, dates.min(), dates.max(), color='gray', alpha=0.6, linestyles="dashed")  # Base timeline
plt.scatter(dates, [1]*len(dates), color="red", s=100, zorder=5)  # Timeline points

# Add labels and vertical lines for better clarity
for i, (txt, pos, align) in enumerate(zip(labels, positions, alignments)):
    plt.text(dates[i], pos, txt, ha="center", fontsize=10, verticalalignment=align)
    plt.vlines(dates[i], 0.95, 1.05, color='gray', linestyles="dotted")

# Formatting the plot
plt.title("Our Relationship Timeline ❤️", fontsize=14)
plt.yticks([])
plt.xticks(rotation=30)  # Rotate x-axis labels
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Favourite Date Spots Analysis

# %%
data = {'Place': ['Cafe', 'Movies', 'Adventures', 'Costco', 'Home', 'Gym', 'Sport Games'],
        'Visits': [5, 8, 7, 20, 25,3,7]}

df = pd.DataFrame(data)

plt.figure(figsize=(8, 5))
sns.barplot(x='Place', y='Visits', data=df, palette="magma")
plt.title("Our Favorite Date Spots ❤️")
plt.show()
# Out:
# <ipython-input-10-90c5c55a7052>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Place', y='Visits', data=df, palette="magma")

# %% [markdown]
# ## Our Favorite Places
#
# | Place                  | Type        | Visits |
# |------------------------|------------|--------|
# | Williams Cafe         | Cafe        | 10     |
# | Lancaster Smokehouse  | Restaurant  | 15     |
#
# Williams Cafe is special because it's where we **first met**. ❤️

# %% [markdown]
# ## Places We've Traveled Together
#
# - 🌴 **San Juan Del Sur, Nicaragua** (April 27, 2024 - First trip together)
# - 🍁 **Tobermory, Canada**
# - 🎄 **Toronto Christmas Market**
# - 🗽 **Buffalo & Rochester, NY**
#
# ### 📌 Future Travel Wishlist
# We would love to visit **New York and Boston** next! ✈️

# %% [markdown]
# ## Frequency of Messages

# %%
# Simulated daily message frequency
days = np.arange(days_together)
messages_per_day = np.random.randint(10, 15, size=days_together)

plt.figure(figsize=(10, 5))
plt.plot(days, messages_per_day, color='purple')
plt.title("Messages Sent Per Day ❤️")
plt.xlabel("Days Together")
plt.ylabel("Messages Count")
plt.show()

print("Most used emojis: 😂 (laughing) and ❤️ (red heart)")
print("Inside joke: 'Witcha!' - A funny action noise we use")
# Out:
# Most used emojis: 😂 (laughing) and ❤️ (red heart)
# Inside joke: 'Witcha!' - A funny action noise we use

# %% [markdown]
# ## Predicting our Anniversary in 10 Years

# %%
future_anniversary = start_date.replace(year=start_date.year + 10)
print(f"In 10 years, our anniversary will be on {future_anniversary.strftime('%A, %B %d, %Y')}!")
# Out:
# In 10 years, our anniversary will be on Sunday, January 22, 2034!

# %% [markdown]
# ## A Love Letter to Pookems! ❤️

# %% [markdown]
# This notebook is just a small way to show how much I appreciate and love you. Our love is more than just numbers and graphs—it’s about every moment we’ve shared. Happy Valentine’s Day, Kirsten! Be my Valentine? ❤️
